# %% [markdown]
# # Preprocessing

# %%
# Import the necessary libraries
import pandas as pd
import requests
from io import StringIO

# URL of the CSV file
url = "https://static.bc-edx.com/data/dl-1-2/m21/lms/starter/charity_data.csv"

# Download the CSV file content using requests
response = requests.get(url)

# Check if the request was successful
if response.status_code == 200:
    # Read the CSV data from the response content
    application_df = pd.read_csv(StringIO(response.text))
    # Display the first few rows of the DataFrame
    print(application_df.head())
else:
    # Print an error message if the request failed
    print("Failed to download the CSV file")
# Out:
#         EIN                                      NAME APPLICATION_TYPE  \
# 0  10520599              BLUE KNIGHTS MOTORCYCLE CLUB              T10
# 1  10531628    AMERICAN CHESAPEAKE CLUB CHARITABLE TR               T3
# 2  10547893        ST CLOUD PROFESSIONAL FIREFIGHTERS               T5
# 3  10553066            SOUTHSIDE ATHLETIC ASSOCIATION               T3
# 4  10556103  GENETIC RESEARCH INSTITUTE OF THE DESERT               T3
#
#         AFFILIATION CLASSIFICATION      USE_CASE  ORGANIZATION  STATUS  \
# 0       Independent          C1000    ProductDev   Association       1
# 1       Independent          C2000  Preservation  Co-operative       1
# 2  CompanySponsored          C3000    ProductDev   Association       1
# 3  CompanySponsored          C2000  Preservation         Trust       1
# 4       Independent          C1000     Heathcare         Trust       1
#
#       INCOME_AMT SPECIAL_CONSIDERATIONS  ASK_AMT  IS_SUCCESSFUL
# 0              0                      N     5000              1
# 1         1-9999                      N   108590              1
# 2              0                      N     5000              0
# 3    10000-24999                      N     6692              1
# 4  100000-499999                      N   142590              1

# %%
# Drop the non-beneficial ID columns, 'EIN'.
application_df = application_df.drop(columns=['EIN'], axis=1)
application_df.head()
# Out:
#                                        NAME APPLICATION_TYPE  \
# 0              BLUE KNIGHTS MOTORCYCLE CLUB              T10
# 1    AMERICAN CHESAPEAKE CLUB CHARITABLE TR               T3
# 2        ST CLOUD PROFESSIONAL FIREFIGHTERS               T5
# 3            SOUTHSIDE ATHLETIC ASSOCIATION               T3
# 4  GENETIC RESEARCH INSTITUTE OF THE DESERT               T3
#
#         AFFILIATION CLASSIFICATION      USE_CASE  ORGANIZATION  STATUS  \
# 0       Independent          C1000    ProductDev   Association       1
# 1       Independent          C2000  Preservation  Co-operative       1
# 2  CompanySponsored          C3000    ProductDev   Association       1
# 3  CompanySponsored          C2000  Preservation         Trust       1
# 4       Independent          C1000     Heathcare         Trust       1
#
#       INCOME_AMT SPECIAL_CONSIDERATIONS  ASK_AMT  IS_SUCCESSFUL
# 0              0                      N     5000              1
# 1         1-9999                      N   108590              1
# 2              0                      N     5000              0
# 3    10000-24999                      N     6692              1
# 4  100000-499999                      N   142590              1

# %%
# Determine the number of unique values in each column.
application_df.nunique()
# Out:
# NAME                      19568
# APPLICATION_TYPE             17
# AFFILIATION                   6
# CLASSIFICATION               71
# USE_CASE                      5
# ORGANIZATION                  4
# STATUS                        2
# INCOME_AMT                    9
# SPECIAL_CONSIDERATIONS        2
# ASK_AMT                    8747
# IS_SUCCESSFUL                 2
# dtype: int64

# %%
# Look at NAME value counts for binning
name_counts = application_df['NAME'].value_counts()
#  How many name counts are greater than 5?
name_counts[name_counts>5]
# Out:
# NAME
# PARENT BOOSTER USA INC                             1260
# TOPS CLUB INC                                       765
# UNITED STATES BOWLING CONGRESS INC                  700
# WASHINGTON STATE UNIVERSITY                         492
# AMATEUR ATHLETIC UNION OF THE UNITED STATES INC     408
#                                                    ...
# OLD OAK CLIFF CONSERVATION LEAGUE INC                 6
# AMERICAN NEPHROLOGY NURSES ASSOCIATION                6
# HUMBLE ISD EDUCATIONAL SUPPORT GROUPS INC             6
# PROFESSIONAL LOADMASTER ASSOCIATION                   6
# CBMC INC                                              6
# Name: count, Length: 354, dtype: int64

# %%
# Determine which values to replace if counts are less than or equal to 5.
names_to_replace = list(name_counts[name_counts <= 5].index)

# Replace in dataframe
for nm in names_to_replace:
    application_df['NAME'] = application_df['NAME'].replace(nm,"Other")
    
# Check to make sure binning was successful
application_df['NAME'].value_counts()
# Out:
# NAME
# Other                                           20043
# PARENT BOOSTER USA INC                           1260
# TOPS CLUB INC                                     765
# UNITED STATES BOWLING CONGRESS INC                700
# WASHINGTON STATE UNIVERSITY                       492
#                                                 ...
# HABITAT FOR HUMANITY INTERNATIONAL                  6
# DAMAGE PREVENTION COUNCIL OF TEXAS                  6
# FLEET RESERVE ASSOCIATION                           6
# HUGH OBRIAN YOUTH LEADERSHIP                        6
# INTERNATIONAL CONGRESS OF CHURCHES MINISTERS        6
# Name: count, Length: 355, dtype: int64

# %%
# Look at APPLICATION_TYPE value counts for binning
application_type_counts = application_df['APPLICATION_TYPE'].value_counts()
application_type_counts
# Out:
# APPLICATION_TYPE
# T3     27037
# T4      1542
# T6      1216
# T5      1173
# T19     1065
# T8       737
# T7       725
# T10      528
# T9       156
# T13       66
# T12       27
# T2        16
# T25        3
# T14        3
# T29        2
# T15        2
# T17        1
# Name: count, dtype: int64

# %%
# Choose a cutoff value and create a list of application types to be replaced
# use the variable name `application_types_to_replace`
#  YOUR CODE GOES HERE
application_types_to_replace = list(application_type_counts[application_type_counts < 1000].index)


# Replace in dataframe
for app in application_types_to_replace:
    application_df['APPLICATION_TYPE'] = application_df['APPLICATION_TYPE'].replace(app,"Other")

# Check to make sure binning was successful
application_df['APPLICATION_TYPE'].value_counts()
# Out:
# APPLICATION_TYPE
# T3       27037
# Other     2266
# T4        1542
# T6        1216
# T5        1173
# T19       1065
# Name: count, dtype: int64

# %%
# Look at CLASSIFICATION value counts for binning
classification_counts = application_df['CLASSIFICATION'].value_counts()
classification_counts
# Out:
# CLASSIFICATION
# C1000    17326
# C2000     6074
# C1200     4837
# C3000     1918
# C2100     1883
#          ...
# C4120        1
# C8210        1
# C2561        1
# C4500        1
# C2150        1
# Name: count, Length: 71, dtype: int64

# %%
# Choose a cutoff value and create a list of classifications to be replaced
# use the variable name `classifications_to_replace`
#  YOUR CODE GOES HERE
classifications_to_replace = list(classification_counts[classification_counts<1000].index)
# Replace in dataframe
for cls in classifications_to_replace:
    application_df['CLASSIFICATION'] = application_df['CLASSIFICATION'].replace(cls,"Other")
    
# Check to make sure binning was successful
application_df['CLASSIFICATION'].value_counts()
# Out:
# CLASSIFICATION
# C1000    17326
# C2000     6074
# C1200     4837
# Other     2261
# C3000     1918
# C2100     1883
# Name: count, dtype: int64

# %%
# Convert categorical data to numeric with `pd.get_dummies`
application_dummies_df = pd.get_dummies(application_df)
application_dummies_df.head()
# Out:
#    STATUS  ASK_AMT  IS_SUCCESSFUL  NAME_AACE INTERNATIONAL  \
# 0       1     5000              1                    False
# 1       1   108590              1                    False
# 2       1     5000              0                    False
# 3       1     6692              1                    False
# 4       1   142590              1                    False
#
#    NAME_ACE MENTOR PROGRAM OF AMERICA INC  \
# 0                                   False
# 1                                   False
# 2                                   False
# 3                                   False
# 4                                   False
#
#    NAME_AFRICAN-AMERICAN POSTAL LEAGUE UNITED FOR SUCCESS A-PLUS  \
# 0                                              False
# 1                                              False
# 2                                              False
# 3                                              False
# 4                                              False
#
#    NAME_AIR FORCE ASSOCIATION  NAME_ALABAMA FEDERATION OF WOMENS CLUBS  \
# 0                       False                                    False
# 1                       False                                    False
# 2                       False                                    False
# 3                       False                                    False
# 4                       False                                    False
#
#    NAME_ALABAMA TREASURE FOREST ASSOCIATION  \
# 0                                     False
# 1                                     False
# 2                                     False
# 3                                     False
# 4                                     False
#
#    NAME_ALBANY STATE UNIVERSITY NATIONAL ALUMNI ASSOCIATION  ...  \
# 0                                              False         ...
# 1                                              False         ...
# 2                                              False         ...
# 3                                              False         ...
# 4                                              False         ...
#
#    INCOME_AMT_1-9999  INCOME_AMT_10000-24999  INCOME_AMT_100000-499999  \
# 0              False                   False                     False
# 1               True                   False                     False
# 2              False                   False                     False
# 3              False                    True                     False
# 4              False                   False                      True
#
#    INCOME_AMT_10M-50M  INCOME_AMT_1M-5M  INCOME_AMT_25000-99999  \
# 0               False             False                   False
# 1               False             False                   False
# 2               False             False                   False
# 3               False             False                   False
# 4               False             False                   False
#
#    INCOME_AMT_50M+  INCOME_AMT_5M-10M  SPECIAL_CONSIDERATIONS_N  \
# 0            False              False                      True
# 1            False              False                      True
# 2            False              False                      True
# 3            False              False                      True
# 4            False              False                      True
#
#    SPECIAL_CONSIDERATIONS_Y
# 0                     False
# 1                     False
# 2                     False
# 3                     False
# 4                     False
#
# [5 rows x 396 columns]

# %%
# Split our preprocessed data into our features and target arrays
X = application_dummies_df.drop(["IS_SUCCESSFUL"], axis='columns').values
y = application_dummies_df["IS_SUCCESSFUL"].values

# Split the preprocessed data into a training and testing dataset
X_train, X_test, y_train, y_test = train_test_split(X, y, random_state=78)

# %%
# Create a StandardScaler instances
scaler = StandardScaler()

# Fit the StandardScaler
X_scaler = scaler.fit(X_train)

# Scale the data
X_train_scaled = X_scaler.transform(X_train)
X_test_scaled = X_scaler.transform(X_test)

# %% [markdown]
# # Compile, Train and Evaluate the Model

# %%
import warnings
warnings.filterwarnings("ignore")
# Define the model - deep neural net, i.e., the number of input features and hidden nodes for each layer.
#  YOUR CODE GOES HERE
number_input_features = len(X_train[0])
hidden_nodes_layer1 =  100
hidden_nodes_layer2 = 30
hidden_nodes_layer3 = 10

nn = tf.keras.models.Sequential()

# First hidden layer
nn.add(
    tf.keras.layers.Dense(units=hidden_nodes_layer1, input_dim=number_input_features, activation="relu")
)

# Second hidden layer
nn.add(tf.keras.layers.Dense(units=hidden_nodes_layer2, activation="tanh"))

# Third hidden layer
nn.add(tf.keras.layers.Dense(units=hidden_nodes_layer3, activation="sigmoid"))

# Output layer
nn.add(tf.keras.layers.Dense(units=1, activation="sigmoid"))

# Check the structure of the model
nn.summary()
# Out:
# Model: "sequential"
# _________________________________________________________________
#  Layer (type)                Output Shape              Param #
# =================================================================
#  dense (Dense)               (None, 100)               39600
#
#  dense_1 (Dense)             (None, 30)                3030
#
#  dense_2 (Dense)             (None, 10)                310
#
#  dense_3 (Dense)             (None, 1)                 11
#
# =================================================================
# Total params: 42951 (167.78 KB)
# Trainable params: 42951 (167.78 KB)
# Non-trainable params: 0 (0.00 Byte)
# _________________________________________________________________

# %%
# Compile the model
nn.compile(loss="binary_crossentropy", optimizer="adam", metrics=["accuracy"])

# %%
# Train the model
fit_model = nn.fit(X_train_scaled,y_train,epochs=100)
# Out:
# Epoch 1/100
# 804/804 [==============================] - 17s 11ms/step - loss: 0.4861 - accuracy: 0.7781
# Epoch 2/100
# 804/804 [==============================] - 9s 12ms/step - loss: 0.4411 - accuracy: 0.7943
# Epoch 3/100
# 804/804 [==============================] - 12s 15ms/step - loss: 0.4338 - accuracy: 0.7952
# Epoch 4/100
# 804/804 [==============================] - 10s 12ms/step - loss: 0.4301 - accuracy: 0.7954
# Epoch 5/100
# 804/804 [==============================] - 9s 11ms/step - loss: 0.4274 - accuracy: 0.7977
# Epoch 6/100
# 804/804 [==============================] - 8s 10ms/step - loss: 0.4254 - accuracy: 0.7987
# Epoch 7/100
# 804/804 [==============================] - 8s 10ms/step - loss: 0.4243 - accuracy: 0.7978
# Epoch 8/100
# 804/804 [==============================] - 9s 11ms/step - loss: 0.4231 - accuracy: 0.7985
# Epoch 9/100
# 804/804 [==============================] - 8s 11ms/step - loss: 0.4226 - accuracy: 0.7992
# Epoch 10/100
# 804/804 [==============================] - 9s 11ms/step - loss: 0.4210 - accuracy: 0.7999
# Epoch 11/100
# 804/804 [==============================] - 9s 11ms/step - loss: 0.4202 - accuracy: 0.7998
# Epoch 12/100
# 804/804 [==============================] - 9s 12ms/step - loss: 0.4191 - accuracy: 0.7994
# Epoch 13/100
# 804/804 [==============================] - 9s 11ms/step - loss: 0.4188 - accuracy: 0.8013
# Epoch 14/100
# 804/804 [==============================] - 9s 11ms/step - loss: 0.4183 - accuracy: 0.8015
# Epoch 15/100
# 804/804 [==============================] - 8s 10ms/step - loss: 0.4175 - accuracy: 0.8020
# Epoch 16/100
# 804/804 [==============================] - 9s 11ms/step - loss: 0.4170 - accuracy: 0.8025
# Epoch 17/100
# 804/804 [==============================] - 9s 11ms/step - loss: 0.4169 - accuracy: 0.8018
# Epoch 18/100
# 804/804 [==============================] - 9s 11ms/step - loss: 0.4156 - accuracy: 0.8021
# Epoch 19/100
# 804/804 [==============================] - 8s 10ms/step - loss: 0.4155 - accuracy: 0.8030
# Epoch 20/100
# 804/804 [==============================] - 7s 9ms/step - loss: 0.4151 - accuracy: 0.8028
# Epoch 21/100
# 804/804 [==============================] - 8s 10ms/step - loss: 0.4150 - accuracy: 0.8030
# Epoch 22/100
# 804/804 [==============================] - 8s 9ms/step - loss: 0.4142 - accuracy: 0.8032
# Epoch 23/100
# 804/804 [==============================] - 7s 9ms/step - loss: 0.4144 - accuracy: 0.8039
# Epoch 24/100
# 804/804 [==============================] - 7s 9ms/step - loss: 0.4139 - accuracy: 0.8036
# Epoch 25/100
# 804/804 [==============================] - 7s 9ms/step - loss: 0.4136 - accuracy: 0.8040
# Epoch 26/100
# 804/804 [==============================] - 12s 15ms/step - loss: 0.4132 - accuracy: 0.8035
# Epoch 27/100
# 804/804 [==============================] - 13s 17ms/step - loss: 0.4131 - accuracy: 0.8050
# Epoch 28/100
# 804/804 [==============================] - 12s 15ms/step - loss: 0.4130 - accuracy: 0.8046
# Epoch 29/100
# 804/804 [==============================] - 10s 13ms/step - loss: 0.4122 - accuracy: 0.8040
# Epoch 30/100
# 804/804 [==============================] - 10s 13ms/step - loss: 0.4127 - accuracy: 0.8043
# Epoch 31/100
# 804/804 [==============================] - 9s 12ms/step - loss: 0.4122 - accuracy: 0.8048
# Epoch 32/100
# 804/804 [==============================] - 10s 12ms/step - loss: 0.4118 - accuracy: 0.8038
# Epoch 33/100
# 804/804 [==============================] - 9s 11ms/step - loss: 0.4126 - accuracy: 0.8045
# Epoch 34/100
# 804/804 [==============================] - 10s 13ms/step - loss: 0.4123 - accuracy: 0.8047
# Epoch 35/100
# 804/804 [==============================] - 10s 12ms/step - loss: 0.4119 - accuracy: 0.8042
# Epoch 36/100
# 804/804 [==============================] - 9s 12ms/step - loss: 0.4119 - accuracy: 0.8045
# Epoch 37/100
# 804/804 [==============================] - 8s 10ms/step - loss: 0.4116 - accuracy: 0.8052
# Epoch 38/100
# 804/804 [==============================] - 7s 9ms/step - loss: 0.4113 - accuracy: 0.8052
# Epoch 39/100
# 804/804 [==============================] - 8s 10ms/step - loss: 0.4110 - accuracy: 0.8047
# Epoch 40/100
# 804/804 [==============================] - 7s 9ms/step - loss: 0.4112 - accuracy: 0.8052
# Epoch 41/100
# 804/804 [==============================] - 7s 9ms/step - loss: 0.4109 - accuracy: 0.8057
# Epoch 42/100
# 804/804 [==============================] - 7s 9ms/step - loss: 0.4108 - accuracy: 0.8057
# Epoch 43/100
# 804/804 [==============================] - 7s 8ms/step - loss: 0.4102 - accuracy: 0.8061
# Epoch 44/100
# 804/804 [==============================] - 7s 8ms/step - loss: 0.4103 - accuracy: 0.8051
# Epoch 45/100
# 804/804 [==============================] - 8s 9ms/step - loss: 0.4103 - accuracy: 0.8061
# Epoch 46/100
# 804/804 [==============================] - 7s 9ms/step - loss: 0.4099 - accuracy: 0.8059
# Epoch 47/100
# 804/804 [==============================] - 9s 11ms/step - loss: 0.4098 - accuracy: 0.8057
# Epoch 48/100
# 804/804 [==============================] - 7s 9ms/step - loss: 0.4096 - accuracy: 0.8060
# Epoch 49/100
# 804/804 [==============================] - 7s 9ms/step - loss: 0.4097 - accuracy: 0.8062
# Epoch 50/100
# 804/804 [==============================] - 8s 9ms/step - loss: 0.4096 - accuracy: 0.8060
# Epoch 51/100
# 804/804 [==============================] - 7s 9ms/step - loss: 0.4097 - accuracy: 0.8058
# Epoch 52/100
# 804/804 [==============================] - 7s 9ms/step - loss: 0.4093 - accuracy: 0.8069
# Epoch 53/100
# 804/804 [==============================] - 7s 9ms/step - loss: 0.4099 - accuracy: 0.8059
# Epoch 54/100
# 804/804 [==============================] - 7s 9ms/step - loss: 0.4095 - accuracy: 0.8059
# Epoch 55/100
# 804/804 [==============================] - 7s 9ms/step - loss: 0.4094 - accuracy: 0.8061
# Epoch 56/100
# 804/804 [==============================] - 7s 9ms/step - loss: 0.4092 - accuracy: 0.8071
# Epoch 57/100
# 804/804 [==============================] - 7s 9ms/step - loss: 0.4091 - accuracy: 0.8061
# Epoch 58/100
# 804/804 [==============================] - 7s 9ms/step - loss: 0.4092 - accuracy: 0.8064
# Epoch 59/100
# 804/804 [==============================] - 7s 9ms/step - loss: 0.4089 - accuracy: 0.8066
# Epoch 60/100
# 804/804 [==============================] - 7s 9ms/step - loss: 0.4097 - accuracy: 0.8064
# Epoch 61/100
# 804/804 [==============================] - 7s 9ms/step - loss: 0.4092 - accuracy: 0.8064
# Epoch 62/100
# 804/804 [==============================] - 7s 9ms/step - loss: 0.4086 - accuracy: 0.8068
# Epoch 63/100
# 804/804 [==============================] - 7s 9ms/step - loss: 0.4093 - accuracy: 0.8066
# Epoch 64/100
# 804/804 [==============================] - 7s 9ms/step - loss: 0.4090 - accuracy: 0.8071
# Epoch 65/100
# 804/804 [==============================] - 8s 9ms/step - loss: 0.4094 - accuracy: 0.8066
# Epoch 66/100
# 804/804 [==============================] - 8s 9ms/step - loss: 0.4086 - accuracy: 0.8069
# Epoch 67/100
# 804/804 [==============================] - 7s 9ms/step - loss: 0.4084 - accuracy: 0.8064
# Epoch 68/100
# 804/804 [==============================] - 7s 9ms/step - loss: 0.4086 - accuracy: 0.8063
# Epoch 69/100
# 804/804 [==============================] - 8s 10ms/step - loss: 0.4079 - accuracy: 0.8077
# Epoch 70/100
# 804/804 [==============================] - 8s 9ms/step - loss: 0.4085 - accuracy: 0.8070
# Epoch 71/100
# 804/804 [==============================] - 8s 10ms/step - loss: 0.4083 - accuracy: 0.8063
# Epoch 72/100
# 804/804 [==============================] - 8s 9ms/step - loss: 0.4080 - accuracy: 0.8077
# Epoch 73/100
# 804/804 [==============================] - 8s 9ms/step - loss: 0.4080 - accuracy: 0.8073
# Epoch 74/100
# 804/804 [==============================] - 8s 9ms/step - loss: 0.4081 - accuracy: 0.8071
# Epoch 75/100
# 804/804 [==============================] - 8s 10ms/step - loss: 0.4075 - accuracy: 0.8073
# Epoch 76/100
# 804/804 [==============================] - 7s 9ms/step - loss: 0.4078 - accuracy: 0.8074
# Epoch 77/100
# 804/804 [==============================] - 7s 9ms/step - loss: 0.4081 - accuracy: 0.8068
# Epoch 78/100
# 804/804 [==============================] - 8s 10ms/step - loss: 0.4076 - accuracy: 0.8071
# Epoch 79/100
# 804/804 [==============================] - 8s 10ms/step - loss: 0.4078 - accuracy: 0.8067
# Epoch 80/100
# 804/804 [==============================] - 7s 9ms/step - loss: 0.4077 - accuracy: 0.8064
# Epoch 81/100
# 804/804 [==============================] - 7s 9ms/step - loss: 0.4075 - accuracy: 0.8071
# Epoch 82/100
# 804/804 [==============================] - 8s 10ms/step - loss: 0.4084 - accuracy: 0.8064
# Epoch 83/100
# 804/804 [==============================] - 7s 9ms/step - loss: 0.4079 - accuracy: 0.8083
# Epoch 84/100
# 804/804 [==============================] - 8s 10ms/step - loss: 0.4080 - accuracy: 0.8077
# Epoch 85/100
# 804/804 [==============================] - 9s 11ms/step - loss: 0.4082 - accuracy: 0.8071
# Epoch 86/100
# 804/804 [==============================] - 8s 10ms/step - loss: 0.4076 - accuracy: 0.8073
# Epoch 87/100
# 804/804 [==============================] - 8s 10ms/step - loss: 0.4076 - accuracy: 0.8077
# Epoch 88/100
# 804/804 [==============================] - 7s 9ms/step - loss: 0.4080 - accuracy: 0.8068
# Epoch 89/100
# 804/804 [==============================] - 8s 9ms/step - loss: 0.4079 - accuracy: 0.8071
# Epoch 90/100
# 804/804 [==============================] - 8s 10ms/step - loss: 0.4080 - accuracy: 0.8075
# Epoch 91/100
# 804/804 [==============================] - 7s 9ms/step - loss: 0.4074 - accuracy: 0.8075
# Epoch 92/100
# 804/804 [==============================] - 7s 9ms/step - loss: 0.4083 - accuracy: 0.8075
# Epoch 93/100
# 804/804 [==============================] - 7s 9ms/step - loss: 0.4087 - accuracy: 0.8068
# Epoch 94/100
# 804/804 [==============================] - 7s 9ms/step - loss: 0.4080 - accuracy: 0.8071
# Epoch 95/100
# 804/804 [==============================] - 7s 9ms/step - loss: 0.4081 - accuracy: 0.8074
# Epoch 96/100
# 804/804 [==============================] - 7s 8ms/step - loss: 0.4096 - accuracy: 0.8070
# Epoch 97/100
# 804/804 [==============================] - 7s 9ms/step - loss: 0.4078 - accuracy: 0.8079
# Epoch 98/100
# 804/804 [==============================] - 7s 9ms/step - loss: 0.4080 - accuracy: 0.8073
# Epoch 99/100
# 804/804 [==============================] - 7s 9ms/step - loss: 0.4086 - accuracy: 0.8076
# Epoch 100/100
# 804/804 [==============================] - 7s 9ms/step - loss: 0.4081 - accuracy: 0.8073

# %%
# Evaluate the model using the test data
model_loss, model_accuracy = nn.evaluate(X_test_scaled,y_test,verbose=2)
print(f"Loss: {model_loss}, Accuracy: {model_accuracy}")
# Out:
# 268/268 - 3s - loss: 0.4409 - accuracy: 0.7890 - 3s/epoch - 12ms/step
# Loss: 0.44088810682296753, Accuracy: 0.7890378832817078

# %%
# Export our model to HDF5 file
nn.save("AlphabetSoupCharity_Optimization.h5")
